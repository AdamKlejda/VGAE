# %%
import os
path =r'.'
list_of_files = []

for root, dirs, files in os.walk(path):
	for file in files:
		list_of_files.append(os.path.join(root,file))
counter = 118
for name in list_of_files:
    if ".gen" in name:
        counter +=1
        path = "/home/adam/thesis/VGAE/graphs/new_data/new_gene/"+str(counter)+".gen"
        # !cp $name $path
#         print(name)
# Out:
# /bin/bash: -c: linia 0: błąd składni przy nieoczekiwanym znaczniku `('
# /bin/bash: -c: linia 0: `cp ./vertpos_nonn(1)/iters_100000_eps_0.8/1/halloffame.gen "/home/adam/thesis/VGAE/graphs/new_data/new_gene1"'
# /bin/bash: -c: linia 0: błąd składni przy nieoczekiwanym znaczniku `('
# /bin/bash: -c: linia 0: `cp ./vertpos_nonn(1)/iters_100000_eps_0.4/5/halloffame.gen "/home/adam/thesis/VGAE/graphs/new_data/new_gene2"'
# /bin/bash: -c: linia 0: błąd składni przy nieoczekiwanym znaczniku `('
# /bin/bash: -c: linia 0: `cp ./vertpos_nonn(1)/iters_100000_eps_0.4/1/halloffame.gen "/home/adam/thesis/VGAE/graphs/new_data/new_gene3"'
# /bin/bash: -c: linia 0: błąd składni przy nieoczekiwanym znaczniku `('
# /bin/bash: -c: linia 0: `cp ./vertpos_nonn(1)/iters_100000_eps_0.4/10/halloffame.gen "/home/adam/thesis/VGAE/graphs/new_data/new_gene4"'
# /bin/bash: -c: linia 0: błąd składni przy nieoczekiwanym znaczniku `('
# ...
